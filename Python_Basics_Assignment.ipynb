# %% [markdown]
# # 🐍 Python Basics Assignment
#
# ### Name: ____________________
# ### Course: ____________________
# ### Submitted To: ____________________
#
# ---
#
# ## 📘 Introduction
# This assignment covers the basic concepts of Python programming including:
# - Variables
# - Lists & Tuples
# - Functions
# - Loops
# - Conditional Statements
# - Sets

# %% [markdown]
# ## Question 1
# ### What is Python and why is it widely used in Data Analytics? Mention any three reasons.
#
# ### Answer:
# Python is a high-level programming language that is simple and easy to learn. It is widely used in Data Analytics because:
#
# 1. It has powerful libraries like Pandas, NumPy, and Matplotlib.
# 2. Python syntax is simple and readable.
# 3. It can handle large amounts of data efficiently.

# %% [markdown]
# ## Question 2
# ### Explain the difference between List and Tuple in Python.
#
# ### Answer:
#
# | List | Tuple |
# |------|------|
# | Mutable (can be changed) | Immutable (cannot be changed) |
# | Uses square brackets `[]` | Uses parentheses `()` |
# | Slower | Faster |
# | Example: `[1,2,3]` | Example: `(1,2,3)` |

# %% [markdown]
# ## Question 3
# ### What is a function in Python? Why are functions useful?
#
# ### Answer:
# A function is a block of reusable code that performs a specific task.
#
# Functions are useful because:
# - They reduce code repetition.
# - They make code organized and readable.
# - They help in debugging easily.

# %% [markdown]
# ## Question 4
# ### Write a Python program to take a user's name as input and print a greeting message.

# %%
name = input("Enter your name: ")
print("Hello,", name + "! Welcome to Python.")

# %% [markdown]
# ## Question 5
# ### Write a Python program to check whether a number is even or odd using conditional statements.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")

# %% [markdown]
# ## Question 6
# ### Write a program to print numbers from 1 to 10 using a loop.

# %%
for i in range(1, 11):
    print(i)

# %% [markdown]
# ## Question 7
# ### Create a list of five numbers and print the maximum number from the list.

# %%
numbers = [12, 45, 7, 89, 23]

print("Maximum number is:", max(numbers))

# %% [markdown]
# ## Question 8
# ### Write a Python program to remove duplicate values from a list using a set.

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]

unique_numbers = list(set(numbers))

print(unique_numbers)

# %% [markdown]
# ## Question 9
# ### Write a function that returns the square of a number.

# %%
def square(num):
    return num * num

print(square(5))

# %% [markdown]
# ## Question 10
# ### Write a Python program to count how many times a number appears in a list.
#
# Example List:
# ```python
# [2,3,4,2,5,2]
# ```

# %%
numbers = [2,3,4,2,5,2]

count = numbers.count(2)

print("2 appears", count, "times")

# %% [markdown]
# ---
# # ✅ Assignment Completed
#
# ### Thank You
